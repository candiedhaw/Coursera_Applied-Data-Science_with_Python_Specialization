# %% [markdown]
# # DataFram Indexing and Loading

# %%
# !cat resources/week-2/datasets/Admission_Predict.csv
# Out:
# Serial No.,GRE Score,TOEFL Score,University Rating,SOP,LOR ,CGPA,Research,Chance of Admit
# 1,337,118,4,4.5,4.5,9.65,1,0.92
# 2,324,107,4,4,4.5,8.87,1,0.76
# 3,316,104,3,3,3.5,8,1,0.72
# 4,322,110,3,3.5,2.5,8.67,1,0.8
# 5,314,103,2,2,3,8.21,0,0.65
# 6,330,115,5,4.5,3,9.34,1,0.9
# 7,321,109,3,3,4,8.2,1,0.75
# 8,308,101,2,3,4,7.9,0,0.68
# 9,302,102,1,2,1.5,8,0,0.5
# 10,323,108,3,3.5,3,8.6,0,0.45
# 11,325,106,3,3.5,4,8.4,1,0.52
# 12,327,111,4,4,4.5,9,1,0.84
# 13,328,112,4,4,4.5,9.1,1,0.78
# 14,307,109,3,4,3,8,1,0.62
# 15,311,104,3,3.5,2,8.2,1,0.61
# 16,314,105,3,3.5,2.5,8.3,0,0.54
# 17,317,107,3,4,3,8.7,0,0.66
# 18,319,106,3,4,3,8,1,0.65
# 19,318,110,3,4,3,8.8,0,0.63
# 20,303,102,3,3.5,3,8.5,0,0.62
# 21,312,107,3,3,2,7.9,1,0.64
# 22,325,114,4,3,2,8.4,0,0.7
# 23,328,116,5,5,5,9.5,1,0.94
# 24,334,119,5,5,4.5,9.7,1,0.95
# 25,336,119,5,4,3.5,9.8,1,0.97
# 26,340,120,5,4.5,4.5,9.6,1,0.94
# 27,322,109,5,4.5,3.5,8.8,0,0.76
# 28,298,98,2,1.5,2.5,7.5,1,0.44
# 29,295,93,1,2,2,7.2,0,0.46
# ...

# %%
import pandas as pd

df = pd.read_csv('resources/week-2/datasets/Admission_Predict.csv')

df.head #pd introduced new index from 0
# Out:
# <bound method NDFrame.head of      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
# ...

# %%
df = pd.read_csv('resources/week-2/datasets/Admission_Predict.csv', index_col=0)
df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
new_df = df.rename(columns = {'GRE Score': 'GRE Score',
                              'TOEFL Score': 'TOEFL Score',
                              'University Rating': 'University Rating',
                              'SOP': 'Statement of Purpose',
                              'LOR': 'Letter of Recommendation',
                              'CGPA': 'CGPA',
                              'Research': 'Research',
                              'Chance of Admit': 'Chance of Admit'},)
new_df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  Statement of Purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
#
#             LOR   CGPA  Research  Chance of Admit
# Serial No.
# 1            4.5  9.65         1              0.92
# 2            4.5  8.87         1              0.76
# 3            3.5  8.00         1              0.72
# 4            2.5  8.67         1              0.80
# 5            3.0  8.21         0              0.65

# %% [markdown]
# only SOP changes, why

# %%
new_df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'Statement of Purpose',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
#because LOR has a space, did not notice

new_df = new_df.rename(columns = {'LOR ': 'Letter of Recommendation'})
new_df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  Statement of Purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
#
#             Letter of Recommendation  CGPA  Research  Chance of Admit
# Serial No.
# 1                                4.5  9.65         1              0.92
# 2                                4.5  8.87         1              0.76
# 3                                3.5  8.00         1              0.72
# 4                                2.5  8.67         1              0.80
# 5                                3.0  8.21         0              0.65

# %%
#strip the title white space
new_df = new_df.rename(mapper = str.strip, axis = 'columns')
new_df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'Statement of Purpose',
#        'Letter of Recommendation', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
cols = list(df.columns)
cols = [x.lower().strip() for x in cols]
df.columns = cols
df.head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 5                  0             0.65

# %% [markdown]
# # Quering a DataFrame

# %%
#boolean chance of admit>0.7
admit_mask = df['chance of admit']>0.7
admit_mask
# Out:
# Serial No.
# 1       True
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398     True
# 399    False
# 400     True
# Name: chance of admit, Length: 400, dtype: bool

# %%
df.where(admit_mask)
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 2               324.0        107.0                4.0  4.0  4.5  8.87
# 3               316.0        104.0                3.0  3.0  3.5  8.00
# 4               322.0        110.0                3.0  3.5  2.5  8.67
# 5                 NaN          NaN                NaN  NaN  NaN   NaN
# ...               ...          ...                ...  ...  ...   ...
# 396             324.0        110.0                3.0  3.5  3.5  9.04
# 397             325.0        107.0                3.0  3.0  3.5  9.11
# 398             330.0        116.0                4.0  5.0  4.5  9.45
# 399               NaN          NaN                NaN  NaN  NaN   NaN
# 400             333.0        117.0                4.0  5.0  4.0  9.66
#
#             research  chance of admit
# Serial No.
# 1                1.0             0.92
# ...

# %%
df.where(admit_mask).dropna().head() #dropNaN #head show first 5
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 2               324.0        107.0                4.0  4.0  4.5  8.87
# 3               316.0        104.0                3.0  3.0  3.5  8.00
# 4               322.0        110.0                3.0  3.5  2.5  8.67
# 6               330.0        115.0                5.0  4.5  3.0  9.34
#
#             research  chance of admit
# Serial No.
# 1                1.0             0.92
# 2                1.0             0.76
# 3                1.0             0.72
# 4                1.0             0.80
# 6                1.0             0.90

# %%
#devs = where().dropna is often used
df[df['chance of admit']>0.7].head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 6                 330          115                  5  4.5  3.0  9.34
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 6                  1             0.90

# %%
df['gre score'].head()
# Out:
# Serial No.
# 1    337
# 2    324
# 3    316
# 4    322
# 5    314
# Name: gre score, dtype: int64

# %%
df[['gre score', 'toefl score']].head()
# Out:
#             gre score  toefl score
# Serial No.
# 1                 337          118
# 2                 324          107
# 3                 316          104
# 4                 322          110
# 5                 314          103

# %%
df[df['gre score']>320].head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 4                 322          110                  3  3.5  2.5  8.67
# 6                 330          115                  5  4.5  3.0  9.34
# 7                 321          109                  3  3.0  4.0  8.20
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 4                  1             0.80
# 6                  1             0.90
# 7                  1             0.75

# %% [markdown]
# ### combine boolean mask

# %%
(df['chance of admin'>0.7] and df['chance of admin'<0.9])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-a8c6975dbf78> in <module>
# ----> 1 (df['chance of admin'>0.7] and df['chance of admin'<0.9])
#
# TypeError: '>' not supported between instances of 'str' and 'float'

# %% [markdown]
# python don't know how to compare two series

# %%
(df['chance of admit']>0.7) & (df['chance of admit']<0.9)
# Out:
# Serial No.
# 1      False
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398    False
# 399    False
# 400    False
# Name: chance of admit, Length: 400, dtype: bool

# %%
df[(df['chance of admit']>0.7) & (df['chance of admit']<0.9)]
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 7                 321          109                  3  3.0  4.0  8.20
# 12                327          111                  4  4.0  4.5  9.00
# ...               ...          ...                ...  ...  ...   ...
# 393               326          112                  4  4.0  3.5  9.12
# 394               317          104                  2  3.0  3.0  8.76
# 395               329          111                  4  4.5  4.0  9.23
# 396               324          110                  3  3.5  3.5  9.04
# 397               325          107                  3  3.0  3.5  9.11
#
#             research  chance of admit
# Serial No.
# 2                  1             0.76
# ...

# %%
df['chance of admit'].gt(0.7) & df['chance of admit'].lt(0.9)
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 7                 321          109                  3  3.0  4.0  8.20
# 12                327          111                  4  4.0  4.5  9.00
# ...               ...          ...                ...  ...  ...   ...
# 393               326          112                  4  4.0  3.5  9.12
# 394               317          104                  2  3.0  3.0  8.76
# 395               329          111                  4  4.5  4.0  9.23
# 396               324          110                  3  3.5  3.5  9.04
# 397               325          107                  3  3.0  3.5  9.11
#
#             research  chance of admit
# Serial No.
# 2                  1             0.76
# ...

# %%
df['chance of admit'].gt(0.7).lt(0.9)
# Out:
# Serial No.
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
#        ...
# 396    False
# 397    False
# 398    False
# 399     True
# 400    False
# Name: chance of admit, Length: 400, dtype: bool
